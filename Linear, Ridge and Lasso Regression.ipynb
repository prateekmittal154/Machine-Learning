# %% [markdown]
# # Linear Rigression, Ridge and Lasso Regression

# %%
# house pricing datasets

from sklearn.datasets import load_boston

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=load_boston()

# %%
dataset= pd.DataFrame(df.data)
dataset.columns = df.feature_names
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
# Dividing the dataset into Dependent & Independent features


X= dataset.iloc[:,:-1] # Independent Features
y= dataset.iloc[:,-1]  # Dependent Features

# %%
## Linear Regression

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

linear_reg=LinearRegression(normalize=True)
mse= cross_val_score(linear_reg,X,y,scoring='neg_mean_squared_error',cv=100)
mse_mean=np.mean(mse)
print(mse_mean)

model.fit(X,y)
predicted=model.fit(X,y)
predicted = model.predict(X)
print(predicted)
# Out:
# -19.776778933199918
# [ 9.0492534  11.30317638  6.3857795   5.66947567  5.74393112  9.32484659
#  12.41888794 14.38915497 17.23287642 14.40649886 13.42877182 13.97316073
#  10.53397712 12.73868669 14.21294385 12.75365541 10.00404815 14.35891318
#  13.44933997 14.32420779 17.72948298 15.05756058 14.49430196 16.69678076
#  15.70730501 17.16635271 16.03881346 15.45285705 13.27981846 11.91314535
#  16.93330777 15.75002908 15.86152588 17.01302828 16.39890684 12.58691288
#  12.55466617 10.66674943  9.1755927   6.12591647  3.70153797  3.17230711
#   6.16958329  5.88500911  9.52805589 10.53245396 10.03105866 13.72283139
#  17.37125118 13.54501366 10.65974559 11.53642635  6.0418613   8.33016274
#  11.89725381  3.74889008  8.46531882  7.11311119  9.15824393 11.53072746
#  14.10335647 15.61217505 11.07429791  7.6815981   6.86196323  6.93422117
#  10.33531254  8.70928632 11.33239437  9.71072908  5.29911799  8.34207012
#   6.89851934  6.08680802  5.82499574  9.37134629 12.03752606  9.99264451
# ...

# %%
# Ridge Regression/ L2 regularisation

from sklearn.linear_model import Ridge

model=Ridge(alpha=0.001, normalize=True)
mse=cross_val_score(model,X,y,scoring='neg_mean_absolute_error', cv=300)
mse_mean=np.mean(mse)
print(mse_mean)

model.fit(X,y)
predicted= model.predict(X)
print(predicted)
# Out:
# -3.0888774356811872
# [ 9.05240349 11.29809378  6.38927958  5.67391691  5.74719038  9.32296095
#  12.41282899 14.37625178 17.21570388 14.39406032 13.41681529 13.96211747
#  10.53404942 12.73943463 14.20926249 12.75535333 10.01284181 14.35567891
#  13.45400454 14.32319464 17.7205369  15.05278816 14.49000475 16.68842155
#  15.7005324  17.15901205 16.03177141 15.44730812 13.27605106 11.91237842
#  16.92534273 15.7428666  15.85722913 17.00545212 16.39229032 12.58519856
#  12.55390902 10.67016103  9.18250388  6.12734129  3.70683057  3.18496717
#   6.17795028  5.89372095  9.52780641 10.53254243 10.03185323 13.71140163
#  17.35364979 13.53629518 10.65307657 11.52640481  6.04425057  8.32959404
#  11.89643694  3.74450829  8.45876159  7.10149977  9.15535505 11.52365207
#  14.09016228 15.5941457  11.06475068  7.67851775  6.85611349  6.93418514
#  10.32922204  8.71459605 11.332377    9.71326995  5.31113073  8.34882277
#   6.90831599  6.09789995  5.84129855  9.37778901 12.03739478  9.99873409
# ...

# %%
# Lasso Regression/L1 regularisation

from sklearn.linear_model import Lasso
model=Lasso(alpha=0.1, normalize=True)
mse= cross_val_score(model,X,y,scoring='neg_mean_absolute_error',cv=200)
mse_mean=np.mean(mse)
print(mse_mean)

model.fit(X,y)
predicted= model.predict(X)
print(predicted)
# Out:
# -4.239342498498755
# [11.19852732 12.23030278  9.77728792  9.22426395  9.23652362 11.03418706
#  12.85060507 13.71022696 15.08747877 13.66627938 13.17503168 13.53104681
#  11.9863438  12.83616824 13.44395948 12.87561004 11.52437389 13.56649903
#  12.90278809 13.65343014 15.18840679 13.93267795 13.63814519 14.72072047
#  14.22736059 14.61071385 14.31980796 13.73182582 12.95626575 12.260458
#  14.70164654 14.13854009 13.66881042 14.76581822 13.95646619 12.90234186
#  12.82808746 11.98536664 11.25757935  9.14647975  7.93418613  8.24591939
#   9.74977301  9.65123226 11.35501471 11.96866023 11.71422336 13.32324793
#  15.14665581 13.31402375 11.73850951 12.11187333  9.48996753 10.65548865
#  11.98278928  7.50399553 10.066032    9.28943954 10.67263785 11.90661976
#  13.11000324 13.72845636 11.56895564  9.87264767  9.41344975  9.6916777
#  11.37202623 10.96267801 12.23755369 11.42638518  9.41495087 10.89045793
#  10.25577414  9.78504012  9.95329009 11.53598496 12.77098957 11.89722881
# ...
